# %% [markdown]
# <a href="https://colab.research.google.com/github/aneesdaz/AI_ChatBot_Python/blob/master/Copy_of_python_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# marks = 89
# if marks >= 90:
#   print("a+")
# elif marks >= 80:
#   print("b+")
# elif marks <= 70:
#   print("c+")
# elif marks <= 60:
#   print("fail")
# Out:
# b+
